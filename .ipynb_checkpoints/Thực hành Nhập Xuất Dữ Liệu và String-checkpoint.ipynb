# %% [markdown]
# ![z4109641517854_eec58201f8d9f52a38de73f7093d90f7.jpg](attachment:z4109641517854_eec58201f8d9f52a38de73f7093d90f7.jpg)

# %%
n=int(input('Nhập số nguyên n ='))
result=n**2
print('kết quả bình phương n=', result) #mình làm
print(f"square of number {n} is {result}") #thầy làm
# Out:
# Nhập số nguyên n =4
# kết quả bình phương n= 16
# square of number 4 is 16

# %%
title = 'No,Fullname,Math,Physics,Chemistry'
data='1,Nguyen Van A,8.0,9.5,7.4'


#Trích xuất ra điểm Toán lý hóa

math_score=float(data[15:18])
physics_score=float(data[19:22])
chemical_score=float(data[23:])

avg_score=round((math_score+physics_score+chemical_score)/3,1)

print(f" math score is {math_score}")
print(f" physics_score is {physics_score}")
print(f" chemical score is {chemistry_score}")
print(f" avg_score is {avg_score}")
# Out:
#  math score is 8.0
#  physics_score is 9.5
#  chemical score is 7.4
#  avg_score is 8.3
