# %% [markdown]
# ![z4091527997546_0729370340a209cd36a35bac099768e0.jpg](attachment:z4091527997546_0729370340a209cd36a35bac099768e0.jpg)

# %%
#Bài 1
điểm_toán =8.5
điểm_lý=7.5
điểm_hóa=8
điểm_TB=(điểm_toán+điểm_lý+điểm_hóa)/3
print(điểm_TB)
print(điểm_TB >= 8)
print(8 > điểm_TB >=6 )
print(điểm_TB < 6)
# Out:
# 8.0
# True
# False
# False

# %% [markdown]
# ![z4091632621326_9fa71345d19b661cf0df4563ba62ca2e.jpg](attachment:z4091632621326_9fa71345d19b661cf0df4563ba62ca2e.jpg)

# %%
#Bài 2
participation = 0.76
course_complete_percent=0.9
final_exam_mark=8
PASS_Point=(participation >=0.75 and course_complete_percent >=0.8 and final_exam_mark>=7.5)
print(PASS_Point)
# Out:
# True

# %% [markdown]
# ![z4091725100457_d55888a78eade0c86eb2074a20b6dec0.jpg](attachment:z4091725100457_d55888a78eade0c86eb2074a20b6dec0.jpg)

# %%
#BÀi 3
velocity_km=33
velocity_m=velocity_km*1000
time_min=60
distint_per_min=velocity_m/time_min
print(distint_per_min)
distint_per_1h12min=(velocity_km/60)*72
print(distint_per_1h12min)
# Out:
# 550.0
# 39.6

# %% [markdown]
# ![z4091804659050_b2ee30e84d1088607a13aecc78aae4d8.jpg](attachment:z4091804659050_b2ee30e84d1088607a13aecc78aae4d8.jpg)

# %%
dài=16
rộng=10
diện_tích=(dài*rộng)
print(diện_tích)
dài_tăng=dài+4
diện_tích_tăng=(dài_tăng*rộng)
print(diện_tích_tăng)
phần_trăm_tăng=((diện_tích_tăng/diện_tích)*100)-100
print(phần_trăm_tăng)
# Out:
# 160
# 200
# 25.0
